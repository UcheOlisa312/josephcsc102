# %% [markdown]
# # `Problem 2`

# %%
x=float(input("Type in value: ", ))
if  x%2 == 0 :
    print ("This number is Even")
else:
    print("This number is Odd")
# Out:
# Type in value: 10001
# This number is Odd

# %% [markdown]
# # `Problem 3`

# %%
R_D_Spend = [165349,162597,153441,144372,142107,131876,134615,130298,120542,123334]
Administration = [136897.8,151377.59,101145.55,118671.85,91391.77,99814.71,147198.87,145530.06,148718.95,108679.17]
Marketing_spend = [471784.1,443898.53,407934.54,383199.62,366168.42,362861.36,127716.82,323876.29,304981.62,133245.65]
State = ["New York","California","Florida","New York","Florida","New York","California","Florida","New York","California"]
Profit = [192261.83,191792.06,191050.39,182901.99,166187.94,156991.12,156122.51,155752.6,152211,149759]

# %%
tab= {'R_D_Spend':R_D_Spend, 'Administration':Administration,  'Marketing_spend':Marketing_spend , 'State':State , 'Profit':Profit}

# %%
tab
# Out:
# {'R_D_Spend': [165349,
#   162597,
#   153441,
#   144372,
#   142107,
#   131876,
#   134615,
#   130298,
#   120542,
#   123334],
#  'Administration': [136897.8,
#   151377.59,
#   101145.55,
#   118671.85,
#   91391.77,
#   99814.71,
#   147198.87,
#   145530.06,
#   148718.95,
#   108679.17],
#  'Marketing_spend': [471784.1,
#   443898.53,
#   407934.54,
#   383199.62,
#   366168.42,
#   362861.36,
#   127716.82,
#   323876.29,
#   304981.62,
#   133245.65],
#  'State': ['New York',
#   'California',
#   'Florida',
#   'New York',
#   'Florida',
#   'New York',
#   'California',
#   'Florida',
#   'New York',
#   'California'],
#  'Profit': [192261.83,
#   191792.06,
#   191050.39,
#   182901.99,
#   166187.94,
#   156991.12,
#   156122.51,
#   155752.6,
#   152211,
#   149759]}

# %%
import pandas

# %%
dir(pandas)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
# ...

# %%
data = pandas.DataFrame(tab)

# %%
data
# Out:
#    R_D_Spend  Administration  Marketing_spend       State     Profit
# 0     165349       136897.80        471784.10    New York  192261.83
# 1     162597       151377.59        443898.53  California  191792.06
# 2     153441       101145.55        407934.54     Florida  191050.39
# 3     144372       118671.85        383199.62    New York  182901.99
# 4     142107        91391.77        366168.42     Florida  166187.94
# 5     131876        99814.71        362861.36    New York  156991.12
# 6     134615       147198.87        127716.82  California  156122.51
# 7     130298       145530.06        323876.29     Florida  155752.60
# 8     120542       148718.95        304981.62    New York  152211.00
# 9     123334       108679.17        133245.65  California  149759.00

# %%
data.to_excel("data1.xlsx",index = False)

# %%
data.head(5)
# Out:
#    R_D_Spend  Administration  Marketing_spend       State     Profit
# 0     165349       136897.80        471784.10    New York  192261.83
# 1     162597       151377.59        443898.53  California  191792.06
# 2     153441       101145.55        407934.54     Florida  191050.39
# 3     144372       118671.85        383199.62    New York  182901.99
# 4     142107        91391.77        366168.42     Florida  166187.94

# %%
data.tail(5)
# Out:
#    R_D_Spend  Administration  Marketing_spend       State     Profit
# 5     131876        99814.71        362861.36    New York  156991.12
# 6     134615       147198.87        127716.82  California  156122.51
# 7     130298       145530.06        323876.29     Florida  155752.60
# 8     120542       148718.95        304981.62    New York  152211.00
# 9     123334       108679.17        133245.65  California  149759.00

# %%
data.columns
# Out:
# Index(['R_D_Spend', 'Administration', 'Marketing_spend', 'State', 'Profit'], dtype='object')

# %%
pandas.read_excel('data1.xlsx')
# Out:
#    R_D_Spend  Administration  Marketing_spend       State     Profit
# 0     165349       136897.80        471784.10    New York  192261.83
# 1     162597       151377.59        443898.53  California  191792.06
# 2     153441       101145.55        407934.54     Florida  191050.39
# 3     144372       118671.85        383199.62    New York  182901.99
# 4     142107        91391.77        366168.42     Florida  166187.94
# 5     131876        99814.71        362861.36    New York  156991.12
# 6     134615       147198.87        127716.82  California  156122.51
# 7     130298       145530.06        323876.29     Florida  155752.60
# 8     120542       148718.95        304981.62    New York  152211.00
# 9     123334       108679.17        133245.65  California  149759.00

# %% [markdown]
# # `Problem 4`

# %%
x = float(input("Input speed of vehicle: ", ))
y = float(input("Input distance travelled by vehicle: ", ))
z = x/y
print("Speed = distance/time")
print(z)
# Out:
# Input speed of vehicle: 50
# Input distance travelled by vehicle: 2
# Speed = distance/time
# 25.0
