# %% [markdown]
# # Uche Joseph
#
# # 20120612131
#
# # joseph.uche@pau.edu.ng

# %% [markdown]
# # Exercise 1
#
# # A python program to get the difference between a given number and 17,if the number is greater than 17 return double the absolute difference
# ![image.png](attachment:image.png)

# %%
x=float(input("type in any  integer", ))
y=17
z=x-y
if x>17:
    d=2*z
    print(d)
else:
    print(z)
# Out:
# type in any positive integer2
# -15.0

# %% [markdown]
# # Exercise 2
#
# # A python program that  caculates the sum of three given numbers, if the valaues are equal then return thrice their sum
#
# ![image.png](attachment:image.png)

# %%
x=float(input("Type in any  integer", ))
y=float(input("Type in another  integer", ))
z=float(input("Type in another  integer", ))
A =x+y+z
if x==y==z:
    S=3*A
    print(S)
else:
    print(A)
# Out:
# type in any positive integer1
# type in another positive integer2
# type in another positive integer3
# 6.0

# %% [markdown]
# # Exercise 3
#
# # A python program which will return true if the two given integer value are equal or their sum or differenc is 5
# ![image.png](attachment:image.png)

# %%
x=float(input("Type in an integer", ))
y=float(input("Type in an integer", ))
A = x+y
B = x-y
if x==y:
    print("Equality = true")
else:
    print("Equality = false")
if A==5:
    print("sum  equal to 5/True ")
else:
    print("sum not equal to 5/False")
if B==5:
    print("difference equal to 5/True")
else:
    print("difference not equal to 5/False")
# Out:
# Type in an integer45
# Type in an integer54
# Equality = false
# sum not equal to 5/False
# difference not equal to 5/False

# %% [markdown]
# # Exercise 4
# # A python program to sort three integers without using conditional statements and loops
# ![image.png](attachment:image.png)

# %%
x=float(input ("Input first number", ))
y=float(input("input second number", ))
z=float(input("input third number", ))

b1=min(x, y, z)
b3=max(x, y, z)
b2=(x+y+z)-a1-a3
print("Sorted numbers are in order of:", b1, b2, b3)
# Out:
# Input first number8
# input second number3
# input third number7
# Sorted numbers are in order of: 3.0 7.0 8.0

# %% [markdown]
# # Exercise
# # A python program that takes a positive integer and returns the sum of the cubeof all small positive integers
# ![image.png](attachment:image.png)
